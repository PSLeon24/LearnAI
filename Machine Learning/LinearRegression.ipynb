# %% [markdown]
# <a href="https://colab.research.google.com/github/PSLeon24/LearnAI/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1, 10)
y = x*6+4
plt.scatter(3, 25)
plt.scatter(4, 32)
plt.scatter(5, 39)
plt.plot(x,y)
plt.show()
